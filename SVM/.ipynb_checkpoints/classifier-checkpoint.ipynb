# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=1000,n_features=2,
                          n_classes=2,n_clusters_per_class=2,
                          n_redundant=0)

# %%
X[:5]
# Out:
# array([[ 1.08401164, -0.99909425],
#        [ 1.29084514, -1.48752021],
#        [ 0.79601906,  0.54701461],
#        [ 0.61708942, -0.72111013],
#        [-0.06427489, -1.84658003]])

# %%
y[:5]
# Out:
# array([1, 1, 1, 1, 0])

# %%
df = pd.DataFrame(X)

# %%
sns.scatterplot(x=df[0],y=df[1],hue=y)
# Out:
# <AxesSubplot: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.25, random_state=42)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel='linear')

# %%
svc.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
svc.coef_
# Out:
# array([[1.64934081, 0.01280837]])

# %%
y_pred = svc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
acc = accuracy_score(y_test,y_pred)
conf_mat = confusion_matrix(y_test,y_pred)
clas_rep = classification_report(y_test,y_pred)

# %%
print(acc),print(conf_mat),print(clas_rep)
# Out:
# 0.896
# [[106  14]
#  [ 12 118]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       120
#            1       0.89      0.91      0.90       130
#
#     accuracy                           0.90       250
#    macro avg       0.90      0.90      0.90       250
# weighted avg       0.90      0.90      0.90       250
# (None, None, None)

# %% [markdown]
# # Hyperparameter tuning

# %%
parameter={
    'C':[0.1,1,10,100,1000],
    'gamma':[1,0.1,0.01,0.001,0.0001],
    'kernel':['linerar']
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_svc=GridSearchCV(SVC(),param_grid=parameter,refit=True,cv=3,verbose=3)

# %%
grid_svc.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV 1/3] END ......C=0.1, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ......C=0.1, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ......C=0.1, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ....C=0.1, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ....C=0.1, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ....C=0.1, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ...C=0.1, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ...C=0.1, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ...C=0.1, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ..C=0.1, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ..C=0.1, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ..C=0.1, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END .C=0.1, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END .C=0.1, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END .C=0.1, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ........C=1, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ........C=1, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ........C=1, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ......C=1, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ......C=1, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ......C=1, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END .....C=1, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END .....C=1, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END .....C=1, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ....C=1, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ....C=1, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ....C=1, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ...C=1, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ...C=1, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ...C=1, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END .......C=10, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END .......C=10, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END .......C=10, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END .....C=10, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END .....C=10, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END .....C=10, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ....C=10, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ....C=10, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ....C=10, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ...C=10, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ...C=10, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ...C=10, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ..C=10, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ..C=10, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ..C=10, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ......C=100, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ......C=100, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ......C=100, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ....C=100, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ....C=100, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ....C=100, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ...C=100, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ...C=100, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ...C=100, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ..C=100, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ..C=100, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ..C=100, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END .C=100, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END .C=100, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END .C=100, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END .....C=1000, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END .....C=1000, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END .....C=1000, gamma=1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ...C=1000, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ...C=1000, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ...C=1000, gamma=0.1, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END ..C=1000, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END ..C=1000, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END ..C=1000, gamma=0.01, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END .C=1000, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END .C=1000, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END .C=1000, gamma=0.001, kernel=linerar;, score=nan total time=   0.0s
# [CV 1/3] END C=1000, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 2/3] END C=1000, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# [CV 3/3] END C=1000, gamma=0.0001, kernel=linerar;, score=nan total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 grid_svc.fit(X_train,y_train)
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1389, in GridSearchCV._run_search(self, evaluate_candidates)
#    1387 def _run_search(self, evaluate_candidates):
#    1388     """Search all candidates in param_grid"""
# -> 1389     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_search.py:852, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     845 elif len(out) != n_candidates * n_splits:
#     846     raise ValueError(
#     847         "cv.split and cv.get_n_splits returned "
#     848         "inconsistent results. Expected {} "
#     849         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     850     )
# --> 852 _warn_or_raise_about_fit_failures(out, self.error_score)
#     854 # For callable self.scoring, the return type is only know after
#     855 # calling. If the return type is a dictionary, the error scores
#     856 # can now be inserted with the correct key. The type checking
#     857 # of out will be done in `_insert_error_scores`.
#     858 if callable(self.scoring):
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 75 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 75 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/svm/_base.py", line 180, in fit
#     self._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 570, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVC must be a str among {'linear', 'precomputed', 'sigmoid', 'rbf', 'poly'} or a callable. Got 'linerar' instead.
