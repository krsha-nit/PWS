# %% [markdown]
# Flight Price:

# %% [markdown]
# ### Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?
#     Ans. (10683, 11)
#
# ### Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.
# ### Q3. What is the range of prices in the dataset? What is the minimum and maximum price?
#     Ans. (1759, 79512)
#
# ### Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.
# ### Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.
#     Ans. Yes there are.
# #### How outliers impact your analysis:
#
#         Influence on Descriptive Statistics: Outliers can significantly impact summary statistics like the mean and standard deviation. The mean is sensitive to extreme values, leading to a skewed representation of the central tendency. The standard deviation may also be affected, potentially overestimating or underestimating the data's variability.
#
#         Distortion of Relationships: Outliers can distort the relationships between variables. In regression analysis, for example, a single outlier with extreme values can drastically change the regression line, affecting the model's predictive capabilities.
#
#         Model Performance: In machine learning, outliers can have a detrimental impact on model performance. They may lead to overfitting if the model tries to fit the noise caused by outliers.
#
#         Data Normality and Assumptions: Outliers can violate the assumptions of normality in statistical tests, leading to unreliable results.
#
#         Data Interpretation: Outliers can introduce bias and misinterpretation when analyzing and interpreting data. It is crucial to understand the reasons for outliers before deciding how to handle them.
#
# #### Handling outliers:
#
#         Depending on the specific context and data characteristics, there are different ways to handle outliers:
#
#         Remove Outliers: If the outliers are due to data entry errors or other anomalies, you can consider removing them from the data set. However, be cautious, as removing too many outliers might lead to loss of valuable information.
#
#         Transform Data: Applying data transformations, such as log transformation or winsorization, can help reduce the impact of outliers.
#
#         Robust Models: Consider using robust statistical methods or machine learning models that are less sensitive to outliers.
#
#         Domain Knowledge: Understand the domain and context of the data to determine whether outliers are genuine, rare events, or errors.
#
# ### Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?
#     Ans. To identify the peak travel season from the Flight Price dataset, there are several key features you can analyze. Here's a step-by-step approach:
#
#     Date and Time Features: Analyze the date and time-related features such as "Departure Date," "Departure Time," "Arrival Date," and "Arrival Time." These features will help identify patterns in flight prices over different months, days of the week, and times of the day.
#     Seasonal Trends: Calculate the average flight prices for each month or quarter of the year to identify seasonal trends. Look for months with consistently higher or lower average prices.
#     Holidays and Special Events: Check for the presence of holidays, festivals, or major events during specific periods. These events can significantly impact travel demand and, consequently, flight prices.
#     Flight Route and Destination: Analyze how flight prices vary for different routes and destinations. Some routes may have higher demand during specific seasons due to weather conditions or cultural events.
#     Booking Lead Time: Examine how the time between booking a flight and the departure date affects flight prices. Certain seasons might have higher demand, leading to increased prices for last-minute bookings.
#     Historical Data: Look at historical flight prices for the past few years to identify patterns and recurring peak seasons.
#     Visualization: Create visualizations such as line plots, bar charts, or heatmaps to showcase the trends in flight prices over time and identify the peak season more intuitively.
#
#
#     After analyzing these features, you can present your findings to your boss in the following manner:
#
#     Executive Summary: Start with a brief executive summary outlining the purpose of the analysis and your main findings.
#     Peak Travel Season: Clearly state the identified peak travel season(s) based on the analysis of flight prices. This could be a specific month, quarter, or time frame.
#     Seasonal Trends: Provide visualizations and a summary of seasonal trends in flight prices. Highlight months with higher and lower average prices.
#     Holidays and Special Events: Identify any major holidays or events that coincide with the peak travel season. Explain how these events might be influencing the demand for flights.
#     Booking Lead Time: Discuss how the lead time for booking flights impacts prices, especially during peak travel seasons.
#     Flight Route and Destination: Mention any specific flight routes or destinations that experience significant price fluctuations during the peak season.
#     Historical Data Analysis: Summarize any recurring patterns observed in historical flight price data that support your findings.
#     Recommendations: Based on the analysis, provide recommendations to the travel agency on how to optimize pricing and marketing strategies during the peak season.
#     Limitations: Acknowledge any limitations of the analysis, such as data availability or external factors that might not have been considered.
#     Data Visualization: Include relevant visualizations to support your findings and make the presentation more engaging.
#
# ### Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?
#     Ans. Same as Q.6
# ### Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?
#     Ans. Same as Q.6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel('flight_price.xlsx')
df.shape
# Out:
# (10683, 11)

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# ### Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
sns.histplot(df['Price'], kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# ### Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df['Price'].min(), df['Price'].max()
# Out:
# (1759, 79512)

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: >

# %% [markdown]
# ### Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
import plotly.express as px
plt.figure(figsize=(10,30))
box_plot = px.box(data_frame=df, y= 'Price', color = 'Airline')
box_plot.show()
# Out:
# <div>                            <div id="9e6a56de-555f-4967-88d0-6e0afc4cdcc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e6a56de-555f-4967-88d0-6e0afc4cdcc3")) {                    Plotly.newPlot(                        "9e6a56de-555f-4967-88d0-6e0afc4cdcc3",                        [{"alignmentgroup":"True","hovertemplate":"Airline=IndiGo<br>Price=%{y}<extra></extra>","legendgroup":"IndiGo","marker":{"color":"#636efa"},"name":"IndiGo","notched":false,"offsetgroup":"IndiGo","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[3897,6218,13302,4174,4804,3943,4823,8238,4423,5894,3943,4377,3943,7191,5894,6297,6893,4049,5894,5636,3540,5780,3540,3943,3597,4804,5636,6442,6147,8855,4777,6442,3419,5073,3858,5775,4804,8738,6412,5013,7048,3943,
# ...

# %% [markdown]
# ### Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %%
df['Date'] = df['Date_of_Journey'].str.split('/').str[0]
df['Month'] = df['Date_of_Journey'].str.split('/').str[1]
df['Year'] = df['Date_of_Journey'].str.split('/').str[2]

average_prices_by_month = df.groupby('Month')['Price'].mean()

plt.figure(figsize=(10, 6))
plt.plot(average_prices_by_month.index, average_prices_by_month.values, marker='o')
plt.xlabel('Month')
plt.ylabel('Average Flight Price')
plt.title('Average Flight Price by Month')
plt.xticks(range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
peak_season = average_prices_by_month.idxmax()
print(f"The peak travel season is in month {peak_season}.")
# Out:
# The peak travel season is in month 03.
