# %%
import pandas as pd

# %%
df =  pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
df.tail()
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass  \
# 513          514         1       1
# 169          170         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 513  Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 169                                   Ling, Mr. Lee    male  28.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 513      0  PC 17603  59.4000   NaN        C
# 169      0      1601  56.4958   NaN        S

# %%
df.columns, df.dtypes, df.shape
# Out:
# (Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object'),
#  PassengerId      int64
#  Survived         int64
#  Pclass           int64
#  Name            object
#  Sex             object
#  Age            float64
#  SibSp            int64
#  Parch            int64
#  Ticket          object
#  Fare           float64
#  Cabin           object
#  Embarked        object
#  dtype: object,
#  (891, 12))

# %%
#to get statical analysis of numerical data, include = 'all' to include categorical data
df.describe()
#df.describe(include = 'all')
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[['Name','Sex','Ticket','Cabin','Embarked']].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
#filter only those data where condition is True
df.dtypes[df.dtypes == 'object']
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
#to filter out int datatype, float 
df[df.dtypes[df.dtypes == 'int64'].index].describe()
df[df.dtypes[df.dtypes == 'float64'].index].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
#slicing operation
df[['Survived','Pclass']][4:11]
df[['Survived','Pclass']][4:11:2]
df[['Survived','Pclass']][11:4:-1]
df[:100:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# ...

# %%
#to add a new column
df['new'] = 0
df.head()

#to add cal field
df['cal'] = df['PassengerId']+df['Pclass']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new  cal
# 0      0         A/5 21171   7.2500   NaN        S    0    4
# 1      0          PC 17599  71.2833   C85        C    0    3
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0    6
# 3      0            113803  53.1000  C123        S    0    5
# ...

# %%
pd.Categorical(df['Pclass']), pd.Categorical(df['Survived']), pd.Categorical(df['Cabin'])
# Out:
# ([3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
#  Length: 891
#  Categories (3, int64): [1, 2, 3],
#  [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
#  Length: 891
#  Categories (2, int64): [0, 1],
#  [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
#  Length: 891
#  Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T'])

# %%
df['Pclass'].nunique(), df['Pclass'].unique()
# Out:
# (3, array([3, 1, 2]))

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new  cal
# 0      0  A/5 21171   7.2500   NaN        S    0    4
# 1      0   PC 17599  71.2833   C85        C    0    3

# %%
#to filter data based on a condtion on a column
df[df['Age']>70], len(df[df['Age']>70]), len(df)-len(df[df['Age']>70])
# Out:
# (     PassengerId  Survived  Pclass                                  Name  \
#  96            97         0       1             Goldschmidt, Mr. George B
#  116          117         0       3                  Connors, Mr. Patrick
#  493          494         0       1               Artagaveytia, Mr. Ramon
#  630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#  851          852         0       3                   Svensson, Mr. Johan
#
#        Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  new  cal
#  96   male  71.0      0      0  PC 17754  34.6542    A5        C    0   98
#  116  male  70.5      0      0    370369   7.7500   NaN        Q    0  120
#  493  male  71.0      0      0  PC 17609  49.5042   NaN        C    0  495
#  630  male  80.0      0      0     27042  30.0000   A23        S    0  632
#  851  male  74.0      0      0    347060   7.7750   NaN        S    0  855  ,
#  5,
#  886)

# %%
#how many people who paid fair less than average
len(df['Fare'] < df['Fare'].mean()),sum(df['Fare'] < df['Fare'].mean()), len(df[df['Fare'] < df['Fare'].mean()])
# Out:
# (891, 680, 680)

# %%
#People who didn't pay any fair
len(df[df['Fare']==0]['Name'])
# Out:
# 15

# %%
df[df['Sex'] =='male'],df[df['Sex'] =='female']
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df[df['Survived'] ==0],df[df['Survived'] ==1]
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#to combine 2 or more filter condition
#combine with AND --filter if both true
df[(df['Sex'] == 'female') & (df['Fare'] > 32)]
#combine with OR --filter if any true
df[(df['Sex'] == 'female') | (df['Fare'] > 32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  new  cal
# 0      0  A/5 21171  7.25   NaN        S    0    4

# %%
#to find person with max fare
df['Fare'].max()
df[df['Fare'] == df['Fare'].max()]
df[df['Fare'] == df['Fare'].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
#row selection
#M1 is slicing approach df[1:10:2]
#M2 using loc and iloc
df.iloc[0:2]
df.loc[0:2]
#loc - named index, iloc - inbuilt index 0 to n even when we have named indec
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new  cal
# 0      0         A/5 21171   7.2500   NaN        S    0    4
# 1      0          PC 17599  71.2833   C85        C    0    3
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0    6

# %%
df.iloc[0:2, ['Survived','Pclass']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df.iloc[0:2, ['Survived','Pclass']]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[0:2, ['Survived','Pclass']]
# Out:
#    Survived  Pclass
# 0         0       3
# 1         1       1
# 2         1       3

# %%
df.iloc[0:2, 1:3]
# Out:
#    Survived  Pclass
# 0         0       3
# 1         1       1

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 644          645         1       3  Baclini, Miss. Eugenie  female  0.75
#
#      SibSp  Parch Ticket     Fare Cabin Embarked  new  cal
# 644      2      1   2666  19.2583   NaN        C    0  648

# %%
df['Name len'] = df['Name'].apply(lambda x: len(x))
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new  cal  Name len
# 0      0  A/5 21171   7.2500   NaN        S    0    4        23
# 1      0   PC 17599  71.2833   C85        C    0    3        51

# %%
df.size, df.shape
# Out:
# (13365, (891, 15))

# %%
891*15
# Out:
# 13365

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
dic = {'email': ['user1.a@dom1.com','user2.a@dom2.com','user3.a@dom3.com','user4.a@dom4.com','user5.a@dom5.com']}
df_email = pd.DataFrame(dic)

# %%
df_email.sample()
df_email['username']=df_email['email'].apply(lambda x: x.split('@')[0])
df_email['domain']=df_email['email'].apply(lambda x: x.split('@')[1]).apply(lambda x: x.split('.')[0])
df_email.head()
# Out:
#               email username domain
# 0  user1.a@dom1.com  user1.a   dom1
# 1  user2.a@dom2.com  user2.a   dom2
# 2  user3.a@dom3.com  user3.a   dom3
# 3  user4.a@dom4.com  user4.a   dom4
# 4  user5.a@dom5.com  user5.a   dom5

# %%
df['Fare'].mean(), df['Fare'].median(), df['Fare'].std()
# Out:
# (32.204207968574636, 14.4542, 49.693428597180905)

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
# Your function should create the following DataFrame:
#
# Date Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
# The function should return the modified DataFrame.

# %%
dt = '2023-03-01'

# %%
dt_ls = []
for i in range(1,10):
    dt = '2023-03-0'+str(i)
    dt_ls.append(dt)

# %%
dt_df = pd.DataFrame(dt_ls,columns=['Date'])
dt_df
# Out:
#          Date
# 0  2023-03-01
# 1  2023-03-02
# 2  2023-03-03
# 3  2023-03-04
# 4  2023-03-05
# 5  2023-03-06
# 6  2023-03-07
# 7  2023-03-08
# 8  2023-03-09

# %%
dt_df['Date'] = pd.to_datetime(dt_df['Date'])

# %%
dt_df.dtypes, dt_df.sample()
# Out:
# (Date    datetime64[ns]
#  dtype: object,
#          Date
#  7 2023-03-08)

# %%
dt_df['WeekDay'] = dt_df['Date'].apply(lambda x: x.strftime('%A'))

# %%
dt_df
# Out:
#         Date    WeekDay
# 0 2023-03-01  Wednesday
# 1 2023-03-02   Thursday
# 2 2023-03-03     Friday
# 3 2023-03-04   Saturday
# 4 2023-03-05     Sunday
# 5 2023-03-06     Monday
# 6 2023-03-07    Tuesday
# 7 2023-03-08  Wednesday
# 8 2023-03-09   Thursday

# %%
df2 = dt_df
df2.sample()
# Out:
#         Date   WeekDay
# 1 2023-03-02  Thursday

# %%
df2[(df2['Date']>'2023-03-06') & (df2['Date']<'2023-03-08')]
# Out:
#         Date  WeekDay
# 6 2023-03-07  Tuesday
