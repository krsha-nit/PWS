# %%
#https://www.simplilearn.com/tutorials/data-analytics-tutorial/percentile-in-statistics

# %%
#quartile - 
'''
q1 -25 percentile
q2 -Median
q3 -75 percentile
'''
# Out:
# '\nq1 -25 percentile\nq2 -Median\nq3 -75 percentile\n'

# %%
# 5 number summary and Boxplot --> to find outlier
'''
1. Minimum
2. Q1
3. Median
4. Q3
5. Maximum
'''
# Out:
# '\n1. Minimum\n2. Q1\n3. Median\n4. Q3\n5. Maximum\n'

# %%
#lower fence = Q1 - 1.5*IQR
#higher fence = Q3 + 1.5*IQR
#IQR = Q3-Q1
#outliers values are those which are not in [lower fence, higher fence]

# %%
x = [1,2,2,2,3,3,4,5,5,5,6,6,6,6,7,8,8,9,29]

# %%
import matplotlib.pyplot as plt
plt.boxplot(x)
plt.grid()

# %%
import numpy as np

# %%
np.quantile(x,0.75)
# Out:
# 6.5

# %%
lst_marks = [45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
minimum, Q1, median, Q3, maximum = np.quantile(lst_marks,[0,0.25,0.5,0.75,1])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (32.0, 54.0, 67.0, 89.0, 99.0)

# %%
IQR = Q3-Q1
lower_fence = Q1 - 1.5*IQR
higher_fence = Q3 + 1.5*IQR
IQR,lower_fence,higher_fence
# Out:
# (35.0, 1.5, 141.5)

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <AxesSubplot: >

# %%
lst_marks = [-100,-200,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,180]

# %%
sns.boxplot(lst_marks)
# Out:
# <AxesSubplot: >

# %%
lst_marks = np.array([-1000,-200,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,180])
std_marks = np.array([(i-np.mean(lst_marks))/np.std(lst_marks)  for i in lst_marks])

# %%
std_marks.min(),std_marks.max()
# Out:
# (-4.264737131924116, 0.6717439092324421)
