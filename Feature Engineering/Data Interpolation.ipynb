# %%
# 1. Linear interpolation

# %%
import numpy as np
x=np.array(range(1,6))
y=np.array(range(2,12,2))
x,y
# Out:
# (array([1, 2, 3, 4, 5]), array([ 2,  4,  6,  8, 10]))

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
##interpolate using linear interpolation

# %%
x_new = np.linspace(1,5,10)##create new x values
y_interp= np.interp(x_new,x,y)
y_interp
# Out:
# array([ 2.        ,  2.88888889,  3.77777778,  4.66666667,  5.55555556,
#         6.44444444,  7.33333333,  8.22222222,  9.11111111, 10.        ])

# %%
plt.scatter(x_new,y_interp)

# %%
#2. cubic interpolation

# %%
x=np.array(range(1,6))
y=np.array([i**3 for i in x])
x,y
# Out:
# (array([1, 2, 3, 4, 5]), array([  1,   8,  27,  64, 125]))

# %%
from scipy.interpolate import interp1d

# %%
#create a cubic interpolation function
f=interp1d(x,y,kind='cubic')

# %%
x_new = np.linspace(1,5,10)
y_interp=f(x_new)
y_interp
# Out:
# array([  1.        ,   3.01371742,   6.739369  ,  12.7037037 ,
#         21.43347051,  33.45541838,  49.2962963 ,  69.48285322,
#         94.54183813, 125.        ])

# %%
plt.scatter(x,y),plt.scatter(x_new,y_interp)
# Out:
# (<matplotlib.collections.PathCollection at 0x7fd0a52a7040>,
#  <matplotlib.collections.PathCollection at 0x7fd0a52a46a0>)

# %%
#3. polynomial interpolation

# %%
x=np.array(range(1,6))
y=np.array([i**2 for i in x])
x,y
# Out:
# (array([1, 2, 3, 4, 5]), array([ 1,  4,  9, 16, 25]))

# %%
p=np.polyfit(x,y,2)

# %%
x_new = np.linspace(1,5,10)
y_interp=np.polyval(p,x_new)
y_interp
# Out:
# array([ 1.        ,  2.08641975,  3.56790123,  5.44444444,  7.71604938,
#        10.38271605, 13.44444444, 16.90123457, 20.75308642, 25.        ])

# %%
plt.scatter(x,y)
plt.scatter(x_new,y_interp)
