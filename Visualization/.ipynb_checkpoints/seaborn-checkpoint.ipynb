# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris.sample()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 114           5.8          2.8           5.1          2.4  virginica

# %%
iris.plot()
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(x=iris.sepal_length,y=iris.sepal_width)
sns.scatterplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=iris)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.pairplot(iris)

# %%
sns.displot(iris['sepal_length']),sns.histplot(iris['sepal_length'])
# Out:
# (<seaborn.axisgrid.FacetGrid at 0x7f19b1753ac0>,
#  <AxesSubplot: xlabel='sepal_length', ylabel='Count'>)

# %%
tips = sns.load_dataset('tips')

# %%
tips.sample()
# Out:
#     total_bill   tip     sex smoker   day   time  size
# 85       34.83  5.17  Female     No  Thur  Lunch     4

# %%
sns.scatterplot(x=tips.total_bill,y=tips.tip)
#sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
tips.sample()
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 239       29.03  5.92  Male     No  Sat  Dinner     3

# %%
tips.smoker.value_counts(),tips['smoker'].value_counts()
# Out:
# (No     151
#  Yes     93
#  Name: smoker, dtype: int64,
#  No     151
#  Yes     93
#  Name: smoker, dtype: int64)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker')
sns.relplot(x=tips.total_bill,y=tips.tip,hue=tips.smoker)

# %%
sns.relplot(x='total_bill',y='tip',data=tips,style='size',hue = 'time') #instead of hue='size'
#hue = color in tableau
#style = shape in tableau

# %%
tips.sample()
# Out:
#      total_bill   tip   sex smoker   day   time  size
# 120       11.69  2.31  Male     No  Thur  Lunch     2

# %%
sns.catplot(x='day',y='total_bill',data = tips)
sns.displot(x='day',y='total_bill',data = tips)
sns.histplot(x='day',y='total_bill',data = tips)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='smoker',y='tip',data = tips)

# %%
sns.jointplot(x=tips.total_bill,y=tips.tip)

# %%
sns.pairplot(tips)

# %%
sns.boxplot(iris)
# Out:
# <AxesSubplot: >

# %%
sns.catplot(x=tips.day,y=tips.total_bill,data=tips)

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x ="timepoint", y = "signal", data = fmri,hue='region',style = 'event')
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.sample()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 498         0       1  female  25.0      1      2  151.55        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 498  woman       False    C  Southampton    no  False

# %%
#sns.boxplot(x ='pclass', y = 'age',data = titanic,hue='survived')
sns.boxplot(x ='pclass', y = 'fare',data = titanic)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.histplot(x=diamonds.price,hue=diamonds.cut)
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#sns.pairplot(iris,hue='species')

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
#list(flights.columns)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.heatmap(flights.pivot(index='year',columns='month',values='passengers'),cmap='coolwarm')
# Out:
# <AxesSubplot: xlabel='month', ylabel='year'>
